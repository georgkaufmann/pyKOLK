# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">pyKOLK</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);"><b style=color:red;>Solution</b> pockets</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# <td><img style="height: 150px;" src="images/pyKOLK.png"></td>
# </tr>
# </table>
#
# ----
# # `pyKOLK`
#
# pyKOLK, a program package prediction the shape of solution pockets in caves from pre-defined climate conditions.

# %%
import numpy as np
import scipy.interpolate
import matplotlib.pyplot as plt
import sys
import libKOLK

# %% [markdown]
# ----
# # Solution pocket -flow model-
# In this notebook, we create all function to model the shape of a solution pocket, driven by pre-defined climate variables.

# %% [markdown]
# ----
# ## Example 3: Driprate variation

# %%
kolkGeom,kolkSave,iSaved,sidex = libKOLK.runKolk_flow(climate='simple',plot=True)
# Out:
# == KOLK ==
#                          path:                work/
#                  sidex [m],nx:       0.40        801
#               init_height [m]:       0.01
#        timestep,timewrite [a]:      10.00       500.00
#         TSoilmin,TSoilmax [C]:       8.00         8.00
#       PSoilmin,PSoilmax [ppm]:     400.00       400.00
#         PAtmmin,PAtmmax [ppm]:     400.00       400.00
#         TCavemin,TCavemax [C]:       8.00         8.00
#       PCavemin,PCavemax [ppm]:    1000.00      1000.00
#   dropCavemin,dropCavemax [s]:      10.00         1.00
#         timeStart,timeEnd [a]:   -5000.00         0.00
# Start time loop ...
# Time step, time [a], TSoil [C]:          1   -4500.00       8.00
# Time step, time [a], TSoil [C]:          2   -4000.00       8.00
# Time step, time [a], TSoil [C]:          3   -3500.00       8.00
# Time step, time [a], TSoil [C]:          4   -3000.00       8.00
# Time step, time [a], TSoil [C]:          5   -2500.00       8.00
# Time step, time [a], TSoil [C]:          6   -2000.00       8.00
# Time step, time [a], TSoil [C]:          7   -1500.00       8.00
# Time step, time [a], TSoil [C]:          8   -1000.00       8.00
# Time step, time [a], TSoil [C]:          9    -500.00       8.00
# Time step, time [a], TSoil [C]:         10       0.00       8.00
# End time loop ...

# %% [markdown]
# ----
