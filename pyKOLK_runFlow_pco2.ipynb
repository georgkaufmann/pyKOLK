# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">pyKOLK</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);"><b style=color:red;>Solution</b> pockets</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# <td><img style="height: 150px;" src="images/pyKOLK.png"></td>
# </tr>
# </table>
#
# ----
# # `pyKOLK`
#
# pyKOLK, a program package prediction the shape of solution pockets in caves from pre-defined climate conditions.

# %%
import numpy as np
import scipy.interpolate
import matplotlib.pyplot as plt
import sys
import libKOLK

# %% [markdown]
# ----
# # Solution pocket -flow model-
# In this notebook, we create all function to model the shape of a solution pocket, driven by pre-defined climate variables.

# %% [markdown]
# ----
# ## Example 2: CO$_2$ difference

# %%
kolkGeom,kolkSave,iSaved,sidex = libKOLK.runKolk_flow(path='div/run_pco2/',climate='seasonP',plot=True)
# Out:
# == KOLK ==
#                          path:        div/run_pco2/
#                  sidex [m],nx:       0.40        801
#               init_height [m]:       0.01
#        timestep,timewrite [a]:       0.08       500.00
#         TSoilmin,TSoilmax [C]:       8.00         8.00
#       PSoilmin,PSoilmax [ppm]:     400.00      1000.00
#         PAtmmin,PAtmmax [ppm]:     400.00       400.00
#         TCavemin,TCavemax [C]:       8.00         8.00
#       PCavemin,PCavemax [ppm]:    1000.00      1000.00
#   dropCavemin,dropCavemax [s]:      10.00        10.00
#         timeStart,timeEnd [a]:   -5000.00         0.00
# Start time loop ...
# Time step, time [a], TSoil [C]:          1   -4499.92       8.00
# Time step, time [a], TSoil [C]:          2   -3999.92       8.00
# Time step, time [a], TSoil [C]:          3   -3499.92       8.00
# IOStream.flush timed out
# Time step, time [a], TSoil [C]:          4   -2999.92       8.00
# IOStream.flush timed out
# Time step, time [a], TSoil [C]:          5   -2499.92       8.00
# Time step, time [a], TSoil [C]:          6   -1999.92       8.00
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# Time step, time [a], TSoil [C]:          7   -1499.92       8.00
# Time step, time [a], TSoil [C]:          8    -999.92       8.00
# Time step, time [a], TSoil [C]:          9    -499.92       8.00
# IOStream.flush timed out
# IOStream.flush timed out
# End time loop ...

# %%
kolkGeom,kolkSave,iSaved,sidex = libKOLK.runKolk_flow(path='div/run_temp_pco2/',climate='seasonTP',plot=True)

# %% [markdown]
# ----
